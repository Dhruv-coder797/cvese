# %%
# STEP 2: Import libraries
import os
import zipfile
import cv2
from skimage.feature import hog
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage.feature import local_binary_pattern
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

# %%
zip_path = "/content/archive (1).zip"
extract_path = "/content/extracted_dataset"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP Extracted Successfully")
# Out:
# ZIP Extracted Successfully

# %%
print(os.listdir(extract_path))
# Out:
# ['fruit-dataset']

# %%
print(os.listdir(extract_path + "/fruit-dataset"))
# Out:
# ['apple', 'orange']

# %%
print(os.listdir(extract_path+"/fruit-dataset"+"/apple"))
# Out:
# ['299.jpeg', '279.jpeg', '111.jpeg', '003.jpeg', '217.jpeg', '277.jpeg', '230.jpeg', '323.jpeg', '093.jpeg', '098.jpeg', '260.jpeg', '370.jpeg', '053.jpeg', '337.jpeg', '106.jpeg', '183.jpeg', '254.jpeg', '244.jpeg', '160.jpeg', '130.jpeg', '374.jpeg', '207.jpeg', '296.jpeg', '118.jpeg', '152.jpeg', '027.jpeg', '095.jpeg', '075.jpeg', '051.jpeg', '088.jpeg', '039.jpeg', '060.jpeg', '064.jpeg', '.ipynb_checkpoints', '295.jpeg', '178.jpeg', '090.jpeg', '094.jpeg', '192.jpeg', '365.jpeg', '041.jpeg', '042.jpeg', '220.jpeg', '050.jpeg', '036.jpeg', '002.jpeg', '284.jpeg', '187.jpeg', '157.jpeg', '232.jpeg', '271.jpeg', '007.jpeg', '251.jpeg', '214.jpeg', '368.jpeg', '397.jpeg', '275.jpeg', '366.jpeg', '067.jpeg', '038.jpeg', '092.jpeg', '018.jpeg', '005.jpeg', '185.jpeg', '197.jpeg', '314.jpeg', '328.jpeg', '361.jpeg', '227.jpeg', '159.jpeg', '161.jpeg', '044.jpeg', '360.jpeg', '381.jpeg', '165.jpeg', '142.jpeg', '089.jpeg', '398.jpeg', '167.jpeg', '013.jpeg', '342.jpeg', '394.jpeg', '076.jpeg', '252.jpeg', '247.jpeg', '234.jpeg', '156.jpeg', '249.jpeg', '334.jpeg', '390.jpeg', '311.jpeg', '147.jpeg', '170.jpeg', '399.jpeg', '242.jpeg', '378.jpeg', '282.jpeg', '132.jpeg', '180.jpeg', '350.jpeg', '047.jpeg', '238.jpeg', '395.jpeg', '281.jpeg', '376.jpeg', '122.jpeg', '123.jpeg', '343.jpeg', '134.jpeg', '008.jpeg', '222.jpeg', '288.jpeg', '221.jpeg', '040.jpeg', '270.jpeg', '173.jpeg', '348.jpeg', '087.jpeg', '285.jpeg', '340.jpeg', '210.jpeg', '177.jpeg', '262.jpeg', '347.jpeg', '211.jpeg', '274.jpeg', '172.jpeg', '255.jpeg', '080.jpeg', '014.jpeg', '307.jpeg', '308.jpeg', '236.jpeg', '286.jpeg', '259.jpeg', '006.jpeg', '068.jpeg', '383.jpeg', '117.jpeg', '302.jpeg', '074.jpeg', '268.jpeg', '310.jpeg', '298.jpeg', '265.jpeg', '086.jpeg', '226.jpeg', '136.jpeg', '171.jpeg', '218.jpeg', '258.jpeg', '291.jpeg', '326.jpeg', '164.jpeg', '124.jpeg', '257.jpeg', '354.jpeg', '091.jpeg', '317.jpeg', '138.jpeg', '363.jpeg', '198.jpeg', '025.jpeg', '121.jpeg', '239.jpeg', '356.jpeg', '015.jpeg', '004.jpeg', '145.jpeg', '203.jpeg', '022.jpeg', '269.jpeg', '055.jpeg', '329.jpeg', '332.jpeg', '033.jpeg', '054.jpeg', '184.jpeg', '382.jpeg', '335.jpeg', '392.jpeg', '175.jpeg', '278.jpeg', '231.jpeg', '103.jpeg', '079.jpeg', '112.jpeg', '297.jpeg', '320.jpeg', '312.jpeg', '264.jpeg', '100.jpeg', '131.jpeg', '024.jpeg', '023.jpeg', '139.jpeg', '141.jpeg', '384.jpeg', '016.jpeg', '313.jpeg', '059.jpeg', '048.jpeg', '362.jpeg', '097.jpeg', '199.jpeg', '261.jpeg', '233.jpeg', '215.jpeg', '030.jpeg', '212.jpeg', '375.jpeg', '351.jpeg', '116.jpeg', '224.jpeg', '305.jpeg', '182.jpeg', '070.jpeg', '315.jpeg', '301.jpeg', '146.jpeg', '294.jpeg', '181.jpeg', '102.jpeg', '001.jpeg', '327.jpeg', '303.jpeg', '273.jpeg', '158.jpeg', '026.jpeg', '043.jpeg', '353.jpeg', '290.jpeg', '120.jpeg', '144.jpeg', '386.jpeg', '190.jpeg', '083.jpeg', '293.jpeg', '078.jpeg', '114.jpeg', '202.jpeg', '191.jpeg', '017.jpeg', '019.jpeg', '188.jpeg', '209.jpeg', '084.jpeg', '011.jpeg', '150.jpeg', '292.jpeg', '062.jpeg', '113.jpeg', '250.jpeg', '391.jpeg', '037.jpeg', '245.jpeg', '319.jpeg', '140.jpeg', '021.jpeg', '331.jpeg', '206.jpeg', '031.jpeg', '246.jpeg', '010.jpeg', '162.jpeg', '263.jpeg', '339.jpeg', '377.jpeg', '155.jpeg', '049.jpeg', '109.jpeg', '189.jpeg', '085.jpeg', '056.jpeg', '333.jpeg', '066.jpeg', '369.jpeg', '373.jpeg', '193.jpeg', '058.jpeg', '169.jpeg', '336.jpeg', '387.jpeg', '213.jpeg', '344.jpeg', '219.jpeg', '020.jpeg', '280.jpeg', '061.jpeg', '065.jpeg', '228.jpeg', '073.jpeg', '283.jpeg', '072.jpeg', '338.jpeg', '149.jpeg', '253.jpeg', '229.jpeg', '243.jpeg', '205.jpeg', '289.jpeg', '096.jpeg', '240.jpeg', '256.jpeg', '316.jpeg', '346.jpeg', '235.jpeg', '201.jpeg', '046.jpeg', '009.jpeg', '267.jpeg', '029.jpeg', '359.jpeg', '082.jpeg', '300.jpeg', '272.jpeg', '276.jpeg', '035.jpeg', '137.jpeg', '195.jpeg', '153.jpeg', '110.jpeg', '379.jpeg', '216.jpeg', '179.jpeg', '349.jpeg', '322.jpeg', '148.jpeg', '388.jpeg', '385.jpeg', '396.jpeg', '166.jpeg', '237. ...

# %%
def preprocess(img):
    img = cv2.resize(img, (128,128))
    # if np.random.rand() > 0.5:
    #     img = cv2.flip(img, 1)  # flip
    # img = cv2.convertScaleAbs(  # brightness and contrast
    #     img,
    #     alpha=np.random.uniform(0.8,1.2),
    #     beta=np.random.randint(-30,30)
    # )
    # angle = np.random.randint(-20,20)  # rotation
    # h, w = img.shape[:2]
    # matrix = cv2.getRotationMatrix2D((w//2, h//2), angle, 1)
    # img1 = cv2.warpAffine(img, matrix, (w,h))
    # img2 = cv2.GaussianBlur(img, (3,3), 0)  # gaussian filtering
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    return img, hsv, gray

# %%
def extract_features(img, hsv, gray):
    features = []

    # 1. HSV Hue Histogram
    hist = cv2.calcHist([hsv], [0], None, [32], [0, 180])
    hist = hist.astype("float32")
    hist /= (hist.sum() + 1e-6)
    features.extend(hist.flatten())

    # 2. Texture (LBP)
    lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')
    lbp_hist, _ = np.histogram(lbp.ravel(), bins=10, range=(0,10))
    lbp_hist = lbp_hist.astype("float32")
    lbp_hist /= (lbp_hist.sum() + 1e-6)
    features.extend(lbp_hist)

    # 3. Shape Features (SAFE)
    edges = cv2.Canny(gray, 100, 200)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    area = sum(cv2.contourArea(c) for c in contours)
    perimeter = sum(cv2.arcLength(c, True) for c in contours)

    # Hard safety guards
    area = np.clip(area, 0, 1e5)
    perimeter = np.clip(perimeter, 0, 1e4)

    circularity = (4 * np.pi * area) / (perimeter**2 + 1e-6)

    features.extend([area, perimeter, circularity])

        # 3. HOG Features
    # hog_features = hog(
    #     gray,
    #     orientations=9,
    #     pixels_per_cell=(8,8),
    #     cells_per_block=(2,2),
    #     visualize=False,
    #     feature_vector=True
    # )
    # hog_features = hog_features.astype("float32")
    # features.extend(hog_features)
    return np.array(features, dtype=np.float32)

# %%
img=cv2.imread('/content/extracted_dataset/fruit-dataset/apple/360.jpeg')
img,hsv,gray=preprocess(img)
edge=cv2.Canny(gray,150,200)
plt.imshow(img)
plt.show()
plt.imshow(hsv[:,:,0],cmap='hsv')
plt.show()
plt.imshow(edge,cmap='gray')
plt.show()
plt.imshow(gray,cmap='gray')
plt.show()

# %%
X=[]
y=[]
base_path='/content/extracted_dataset/fruit-dataset/apple'

for i in os.listdir(base_path):
    try:
        path=os.path.join(base_path,i)
        img=cv2.imread(path)
        img,hsv,gray=preprocess(img)
        features=extract_features(img,hsv,gray)
        X.append(features)
        y.append(0)
    except Exception as e:
        print(e,end='\r')
print()
base_path='/content/extracted_dataset/fruit-dataset/orange'

for i in os.listdir(base_path):
    try:
        path=os.path.join(base_path,i)
        img=cv2.imread(path)
        img,hsv,gray=preprocess(img)
        features=extract_features(img,hsv,gray)
        X.append(features)
        y.append(1)
    except Exception as e:
        print(e,end='\r')
# Out:
# OpenCV(4.13.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
X=np.array(X,dtype='float32')
y=np.array(y)
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
import sklearn

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled,y_resampled, test_size = 0.2, random_state=42, stratify=y_resampled)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
clf = RandomForestClassifier(n_estimators=100,random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# model = LogisticRegression( C=1.0,max_iter=1000, random_state=42)
# model.fit(X_train, y_train)
# model = DecisionTreeClassifier(max_depth=5,min_samples_split=2,random_state=42)
# model.fit(X_train, y_train)
# model = GaussianNB()
# model.fit(X_train, y_train)
# model = GradientBoostingClassifier(n_estimators=100,learning_rate=0.1)
# model.fit(X_train, y_train)
# model = ExtraTreesClassifier(n_estimators=100,max_depth=5)
# model.fit(X_train, y_train)
# model = KNeighborsClassifier(n_neighbors=5)
# model.fit(X_train, y_train)
# model = XGBClassifier(n_estimators=100,learning_rate=0.1)
# model.fit(X_train, y_train)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.30.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBClassifier

# %%
train_sizes, train_scores, test_scores = learning_curve(
    clf,
    X_train,
    y_train,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)

plt.figure(figsize=(10,6))

plt.plot(train_sizes, train_mean, label='Training Accuracy')

plt.plot(train_sizes, test_mean, label='Validation Accuracy')

plt.xlabel('Training Size')

plt.ylabel('Accuracy')

plt.title('Learning Curve')

plt.legend()

plt.grid()

plt.show()

# %%
y_pred = clf.predict(X_test)

classes = ["apple", "orange"]

# Classification Report
print(classification_report(y_test, y_pred, target_names=classes))

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.85      0.94      0.89        80
#       orange       0.93      0.84      0.88        80
#
#     accuracy                           0.89       160
#    macro avg       0.89      0.89      0.89       160
# weighted avg       0.89      0.89      0.89       160
#
# Accuracy: 88.75%

# %%
predicted_labels = [classes[i] for i in y_pred]

actual_labels = [classes[i] for i in y_test]

# %%
results = pd.DataFrame({
    'Actual': actual_labels,
    'Predicted': predicted_labels
})

results.to_csv('classification_results.csv', index=False)

print(results.head())
# Out:
#    Actual Predicted
# 0  orange     apple
# 1   apple     apple
# 2   apple     apple
# 3  orange    orange
# 4  orange    orange

# %%
import requests
import json
url="https://raw.githubusercontent.com/Dhruv-coder797/cvese/main/final.ipynb"
content=requests.get(url).json()
for i,cell in enumerate(content["cells"]):
  print("".join(cell["source"]))
# Out:
# # STEP 2: Import libraries
# import os
# import zipfile
# import cv2
# from skimage.feature import hog
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# from skimage.feature import local_binary_pattern
# from sklearn.model_selection import train_test_split, learning_curve
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import Pipeline
# from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import SVC
# from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.pipeline import Pipeline
# from imblearn.over_sampling import SMOTE
#
# zip_path = "/content/archive (1).zip"
# extract_path = "/content/extracted_dataset"
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)
#
# print("ZIP Extracted Successfully")
# print(os.listdir(extract_path))
# print(os.listdir(extract_path + "/fruit-dataset"))
# print(os.listdir(extract_path+"/fruit-dataset"+"/apple"))
# def preprocess(img):
#     img = cv2.resize(img, (128,128))
#     # if np.random.rand() > 0.5:
#     #     img = cv2.flip(img, 1)  # flip
#     # img = cv2.convertScaleAbs(  # brightness and contrast
#     #     img,
#     #     alpha=np.random.uniform(0.8,1.2),
#     #     beta=np.random.randint(-30,30)
#     # )
#     # angle = np.random.randint(-20,20)  # rotation
#     # h, w = img.shape[:2]
#     # matrix = cv2.getRotationMatrix2D((w//2, h//2), angle, 1)
#     # img = cv2.warpAffine(img, matrix, (w,h))
#     # img = cv2.GaussianBlur(img, (3,3), 0)  # gaussian filtering
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#     return img, hsv, gray
# def extract_features(img, hsv, gray):
#     features = []
#
#     # 1. HSV Hue Histogram
#     hist = cv2.calcHist([hsv], [0], None, [32], [0, 180])
#     hist = hist.astype("float32")
#     hist /= (hist.sum() + 1e-6)
#     features.extend(hist.flatten())
#
#     # 2. Texture (LBP)
#     lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')
#     lbp_hist, _ = np.histogram(lbp.ravel(), bins=10, range=(0,10))
#     lbp_hist = lbp_hist.astype("float32")
#     lbp_hist /= (lbp_hist.sum() + 1e-6)
#     features.extend(lbp_hist)
#
#     # 3. Shape Features (SAFE)
#     edges = cv2.Canny(gray, 100, 200)
#     contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
#     area = sum(cv2.contourArea(c) for c in contours)
#     perimeter = sum(cv2.arcLength(c, True) for c in contours)
#
#     # Hard safety guards
#     area = np.clip(area, 0, 1e5)
#     perimeter = np.clip(perimeter, 0, 1e4)
#
#     circularity = (4 * np.pi * area) / (perimeter**2 + 1e-6)
#
#     features.extend([area, perimeter, circularity])
#
#         # 3. HOG Features
#     # hog_features = hog(
#     #     gray,
#     #     orientations=9,
#     #     pixels_per_cell=(8,8),
#     #     cells_per_block=(2,2),
#     #     visualize=False,
#     #     feature_vector=True
#     # )
#     # hog_features = hog_features.astype("float32")
#     # features.extend(hog_features)
#     return np.array(features, dtype=np.float32)
# img=cv2.imread('/content/extracted_dataset/fruit-dataset/apple/364.jpeg')
# img,hsv,gray=preprocess(img)
# edge=cv2.Canny(gray,150,200)
# plt.imshow(img)
# plt.show()
# plt.imshow(hsv[:,:,0],cmap='hsv')
# plt.show()
# plt.imshow(edge,cmap='gray')
# plt.show()
# plt.imshow(gray,cmap='gray')
# plt.show()
#
# X=[]
# y=[]
# base_path='/content/extracted_dataset/fruit-dataset/apple'
#
# for i in os.listdir(base_path):
#     try:
#         path=os.path.join(base_path,i)
#         img=cv2.imread(path)
#         img,hsv,gray=preprocess(img)
#         features=extract_features(img,hsv,gray)
#         X.append(features)
#         y.append(0)
#     except Exception as e:
#         print(e,end='\r')
# print()
# base_path='/content/extracted_dataset/fruit-dataset/orange'
#
# for i in os.listdir(base_path):
#     try:
#         path=os.path.join(base_path,i)
#         img=cv2.imread(path)
#         img,hsv,gray=preprocess(img)
#         features=extract_features(img,hsv,gray)
#         X.append(features)
#         y.append(1)
#     except Exception as e:
#         print(e,end='\r')
# X=np.array(X,dtype='float32')
# y=np.array(y)
# smote = SMOTE(random_state=42)
# X_resampled, y_resampled = smote.fit_resample(X, y)
# import sklearn
# X_train, X_test, y_train, y_test = train_test_split(X_resampled,y_resampled, test_size = 0.2, random_state=42, stratify=y_resampled)
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# clf = SVC(kernel='linear')
# clf.fit(X_train, y_train)
# clf = RandomForestClassifier(n_estimators = 100, random_state=42)
# clf.fit(X_train, y_train)
# !pip install xgboost
# from xgboost import XGBClassifier
# train_sizes, train_scores, test_scores = learning_curve(
#     clf,
#     X_train,
#     y_train,
#     cv=5,
#     scoring='accuracy',
#     n_jobs=-1,
#     train_sizes=np.linspace(0.1, 1.0, 10)
# )
#
# train_mean = np.mean(train_scores, axis=1)
# test_mean = np.mean(test_scores, axis=1)
#
# plt.figure(figsize=(10,6))
#
# plt.plot(train_sizes, train_mean, label='Training Accuracy')
#
# plt.plot(train_sizes, test_mean, label='Validation Accuracy')
#
# plt.xlabel('Training Size')
#
# plt.ylabel('Accuracy')
#
# plt.title('Learning Curve')
#
# plt.legend()
#
# plt.grid()
#
# plt.show()
# y_pred = clf.predict(X_test)
#
# classes = ["apple", "orange"]
#
# # Classification Report
# print(classification_report(y_test, y_pred, target_names=classes))
#
# # Accuracy
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")
# predicted_labels = [classes[i] for i in y_pred]
#
# actual_labels = [classes[i] for i in y_test]
# results = pd.DataFrame({
#     'Actual': actual_labels,
#     'Predicted': predicted_labels
# })
#
# results.to_csv('classification_results.csv', index=False)
#
# print(results.head())
